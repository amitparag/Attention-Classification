# %% [markdown]
# ### Augmenting the dataset by adding noise, linear contrast and elastic transforms

# %%
# Read https://imgaug.readthedocs.io/en/latest/index.html for more insight

# %%
import cv2
import os
from pathlib import Path
import imgaug as ia
import imageio
from imgaug import augmenters as iaa
import shutil
import argparse
import random

# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.20.0'

# %%
sometimes = lambda aug: iaa.Sometimes(0.5, aug)


def apply_transformations(video_reader,fps,w,h,output_path):
    """
        Fetch each frame of video and augment and save as picture in a temporary folder
        Args:
            video_reader: Video reader object
            rotation_angle: int (Angle of rotation of image)
            noise_value: int (noise value between 0 to 100)
            temp_folder_path: string (temporary path to store video frames)
            output_folder_path: string (output folder path)
            video_clip_name: string (video name)
            i: no of clip augmented
    """
    


    
    #print(editted_name, rotation_angle, "degrees")
    seq = iaa.Sequential([
        #iaa.Fliplr(0.5), # horizontal flips
        #iaa.Crop(percent=(0, 0.1)), # random crops
        # Small gaussian blur with random sigma between 0 and 0.5.
        # But we only blur about 50% of all images.
        iaa.OneOf([
            iaa.GaussianBlur((0, 3.0)),
            iaa.AverageBlur(k=(2, 7)),
            iaa.MedianBlur(k=(3, 11)),
        ]),
        # Strengthen or weaken the contrast in each image.
        sometimes(
            iaa.LinearContrast((0.75, 1.5))
        ),
        sometimes(
            iaa.ElasticTransformation(alpha=(0.5, 3.5), sigma=0.25)
        ),

        # In some images distort local areas with varying strength.
        #sometimes(iaa.PiecewiseAffine(scale=(0.01, 0.05)))
        #)
    ], random_order=True) 

  

    #fourcc = '.avi'  # output video codec
    video_writer = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'XVID'),fps,(w,h))

    try:
        while video_reader.isOpened():
            ret, frame = video_reader.read()
            if not ret:
                break
            image_aug = seq(image=frame)
            video_writer.write(image_aug)
    except Exception as e:
        print(e)

    cv2.destroyAllWindows()
    video_reader.release()
    video_writer.release()

# %%
def get_videos_info(directory, extensions):
    videos_info = []

    for root, dirs, files in os.walk(directory):
        for file in files:
            if any(file.lower().endswith(ext) for ext in extensions):
                videos_info.append({
                    'name': file,
                    'path': os.path.join(root, file),
                    'directory': root
                })

    return videos_info

# %%
def transform_videos(videos_info):
    
    
    for video in videos_info:

        name = video['name']
        path = video['path']
        dir  = video['directory']
        
        print("Processing:", path)
        video_reader = cv2.VideoCapture(path)
        fps = int(video_reader.get(cv2.CAP_PROP_FPS))
        w = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))
        h = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))
                
        transformed_video_path = dir + f'/aug_{name}'
                
        apply_transformations(video_reader,fps,w,h,transformed_video_path)
        print("=" * 40)
    

    print("Complete")

# %%
videos_info = get_videos_info('./dataset/learning/slip', 'avi')

transform_videos(videos_info)
# Out:
# Processing: ./dataset/learning/slip/6098a2ff-456f-49d3-ae61-f1c7611f0ef5.avi
# ========================================
# Processing: ./dataset/learning/slip/cdd1c7b5-5f3b-4b63-b70d-bb641b57133d.avi
# ========================================
# Processing: ./dataset/learning/slip/f05c38fd-96d6-4735-bd9e-2024167c61d7.avi
# ========================================
# Processing: ./dataset/learning/slip/9bc28375-074b-4fb5-b10f-3d3561a70ce6.avi
# ========================================
# Processing: ./dataset/learning/slip/d23e98ba-ff70-45eb-90db-86043b0ab822.avi
# ========================================
# Processing: ./dataset/learning/slip/94561076-4e92-45ee-9f41-6c35a5b9e4c5.avi
# ========================================
# Processing: ./dataset/learning/slip/c4b59cc1-82bd-4630-9bbd-8866c1f55c45.avi
# ========================================
# Processing: ./dataset/learning/slip/75733c3f-879d-445a-8bf1-5ce5b664b9aa.avi
# ========================================
# Processing: ./dataset/learning/slip/9433d939-8df4-49d4-b3b0-52179cbb8172.avi
# ========================================
# Processing: ./dataset/learning/slip/92146be0-db73-4356-8dd9-8874ad7f27d2.avi
# ========================================
# Processing: ./dataset/learning/slip/411387e9-3c83-4349-ba66-7bdb10b93d90.avi
# ========================================
# Processing: ./dataset/learning/slip/9e58ec7b-f70e-41ca-ab64-4da9f41da6eb.avi
# ========================================
# Processing: ./dataset/learning/slip/1c48cd8b-3bab-4c63-af00-bfbcb61cebe6.avi
# ========================================
# Processing: ./dataset/learning/slip/667d2de5-1471-4632-81d5-9482083b8f5e.avi
# ========================================
# Processing: ./dataset/learning/slip/0d77e949-8057-4cec-bb45-3b9c1892ac01.avi
# ========================================
# Processing: ./dataset/learning/slip/19061098-1754-4a54-bdcb-1c49c03419ca.avi
# ========================================
# Processing: ./dataset/learning/slip/f204e839-c864-4da0-94cc-0aa66e193298.avi
# ========================================
# Processing: ./dataset/learning/slip/cc0aa320-bf99-48c4-a243-12a2be7ff4e5.avi
# ========================================
# Processing: ./dataset/learning/slip/9fa61155-eb63-444a-9e3b-2a93fa710922.avi
# ========================================
# Processing: ./dataset/learning/slip/351c6590-1c1b-45f4-8968-a05bb4fa504b.avi
# ========================================
# Processing: ./dataset/learning/slip/06f17251-2ade-4f6f-992e-ab07b3f19527.avi
# ========================================
# Processing: ./dataset/learning/slip/ae8fb8e7-89de-447c-aa0e-8a43afae34e7.avi
# ========================================
# Processing: ./dataset/learning/slip/887f5e44-5159-49cb-863f-e9fd838cffed.avi
# ========================================
# Processing: ./dataset/learning/slip/6387e16e-5bf6-40fe-9826-0f62fcee302d.avi
# ========================================
# Processing: ./dataset/learning/slip/8c5f618f-7141-4fe9-822f-cce4fd1908a2.avi
# ========================================
# Processing: ./dataset/learning/slip/0492d85b-841e-4279-935c-67779edd95e4.avi
# ========================================
# Processing: ./dataset/learning/slip/d431bb05-1cf4-4bb9-a84a-fad51f525cb4.avi
# ========================================
# Processing: ./dataset/learning/slip/454cc72b-fd2a-47b8-af09-25738f2f1e6c.avi
# ========================================
# Processing: ./dataset/learning/slip/6b1654f4-15bb-4ca9-bb7d-3c6dec6d921a.avi
# ========================================
# Processing: ./dataset/learning/slip/bf667229-17d2-44cd-a2a0-c0dafe521fa9.avi
# ========================================
# Processing: ./dataset/learning/slip/b45f580b-1989-466a-8797-ec811e09aa43.avi
# ========================================
# Processing: ./dataset/learning/slip/2ef9f704-0c3e-4811-ad2e-2efbd1384511.avi
# ========================================
# Processing: ./dataset/learning/slip/783b8502-b348-49f2-974c-ced3b1e76e72.avi
# ========================================
# Processing: ./dataset/learning/slip/16768ffe-5114-4236-a04a-6537d4829003.avi
# ========================================
# Processing: ./dataset/learning/slip/a9e10e97-43d8-4e37-9e44-9521a702d680.avi
# ========================================
# Processing: ./dataset/learning/slip/3c67d5db-133d-452c-8d87-be55e049753f.avi
# ========================================
# Processing: ./dataset/learning/slip/49dd7665-2858-4067-8e7f-01da5697336e.avi
# ========================================
# Processing: ./dataset/learning/slip/e10f365d-8491-4649-8012-677844a1bb15.avi
# ========================================
# Processing: ./dataset/learning/slip/12c84870-e577-4983-8ed6-80abd5c611d1.avi
# ========================================
# Processing: ./dataset/learning/slip/d55b1a66-aaed-4ccb-9125-84cc25fcf32d.avi
# ========================================
# Processing: ./dataset/learning/slip/9dc46556-533f-4493-9f19-d242d5878d28.avi
# ========================================
# Processing: ./dataset/learning/slip/23233af0-502b-49a9-9c93-57d2fa074785.avi
# ========================================
# Processing: ./dataset/learning/slip/c2786a1d-edb6-431a-af04-0ee8aec36f2c.avi
# ========================================
# Processing: ./dataset/learning/slip/69af0e37-a9f3-45ff-a258-4fc6f54b7347.avi
# ========================================
# Processing: ./dataset/learning/slip/eeac6473-2dbe-4178-b182-6fa33b1898d0.avi
# ========================================
# Processing: ./dataset/learning/slip/592c12c5-8561-4762-938e-9d89cbab444b.avi
# ========================================
# Processing: ./dataset/learning/slip/5dc39a3b-ee79-4f28-bf56-e7f6fe3c40dc.avi
# ========================================
# Processing: ./dataset/learning/slip/11c37320-2314-468b-8e19-3cd062e9ef3c.avi
# ========================================
# Processing: ./dataset/learning/slip/b96f7e68-62d4-4523-961c-cfdd8e880184.avi
# ========================================
# Processing: ./dataset/learning/slip/e812ead0-823d-4602-9f20-fd0741ec9900.avi
# ========================================
# Processing: ./dataset/learning/slip/cfddb3ca-5736-4e6d-b5e3-efffc0a8ce00.avi
# ========================================
# Processing: ./dataset/learning/slip/65ebbb89-9e66-4dd6-866b-711d4571bf00.avi
# ========================================
# Processing: ./dataset/learning/slip/47cefb3f-194b-4dd9-8753-54558838a3af.avi
# ========================================
# Processing: ./dataset/learning/slip/0ede0fbd-cb9b-4c63-85bb-82c72c8c57d3.avi
# ========================================
# Processing: ./dataset/learning/slip/577cc75f-a0e8-41fd-8cdd-0936c4d89ebc.avi
# ========================================
# Processing: ./dataset/learning/slip/8b201012-ce95-4acc-8f09-3381c0d82c4c.avi
# ========================================
# Processing: ./dataset/learning/slip/a10f91e6-90b6-4912-ac2f-e4007f7fc5cf.avi
# ========================================
# Processing: ./dataset/learning/slip/1e1d9afb-6d24-4daa-ab39-13f9baea3c86.avi
# ========================================
# Processing: ./dataset/learning/slip/56bb691d-fd3d-4429-a31e-625db6c47564.avi
# ========================================
# Processing: ./dataset/learning/slip/a0fd91bc-1af3-4a10-a2da-4d4baf1ab8ea.avi
# ========================================
# Processing: ./dataset/learning/slip/b0a5ca7d-1169-4c36-ab89-7dec0c1de400.avi
# ========================================
# Processing: ./dataset/learning/slip/0c6fe7fe-daef-434b-8409-f4ff2019e746.avi
# ========================================
# Complete

# %%
videos_info = get_videos_info('./dataset/learning/wriggle', 'avi')

transform_videos(videos_info)
# Out:
# Processing: ./dataset/learning/wriggle/ccb41535-34ac-4e9a-adb4-9b57433edf77.avi
# ========================================
# Processing: ./dataset/learning/wriggle/3e0177b2-a603-40c0-9ddd-0cbb1229ecd3.avi
# ========================================
# Processing: ./dataset/learning/wriggle/f4d8da4a-f135-4f1a-a865-c00db127df57.avi
# ========================================
# Processing: ./dataset/learning/wriggle/82036f29-813e-42b4-8cf5-78cee717843e.avi
# ========================================
# Processing: ./dataset/learning/wriggle/bc27977d-ac4a-4493-96ca-ef7fa3321a4c.avi
# ========================================
# Processing: ./dataset/learning/wriggle/cca69360-bb17-4398-9cf0-1cee56b5d814.avi
# ========================================
# Processing: ./dataset/learning/wriggle/06b170a5-0d43-4c65-b29b-28df276cd1f4.avi
# ========================================
# Processing: ./dataset/learning/wriggle/30657f9a-289a-4035-98c3-623d1c2fb022.avi
# ========================================
# Processing: ./dataset/learning/wriggle/1caeb16d-d976-46e2-9aa2-0e262c304771.avi
# ========================================
# Processing: ./dataset/learning/wriggle/f4ff2156-3375-4345-a434-8313e1d5221c.avi
# ========================================
# Processing: ./dataset/learning/wriggle/554ae8d4-2888-4f3e-b638-162474449d24.avi
# ========================================
# Processing: ./dataset/learning/wriggle/ef7ce40e-7eb9-4b42-8105-87c8bece836f.avi
# ========================================
# Processing: ./dataset/learning/wriggle/748fc4a3-5d14-42e7-ae79-1531c41bb592.avi
# ========================================
# Processing: ./dataset/learning/wriggle/4659c33a-d16b-4286-8814-1b3740166b47.avi
# ========================================
# Processing: ./dataset/learning/wriggle/d2ccb76b-6635-48ba-9710-5e7d902aec86.avi
# ========================================
# Processing: ./dataset/learning/wriggle/9bb6723f-79dc-4d42-b357-429804f27251.avi
# ========================================
# Processing: ./dataset/learning/wriggle/734a6a76-4bd6-432b-96f0-90c30bb80311.avi
# ========================================
# Processing: ./dataset/learning/wriggle/3a799fc0-a477-4eb4-9ef5-d1fafa973a4b.avi
# ========================================
# Processing: ./dataset/learning/wriggle/9a98b78e-cfa6-45f5-99f4-196c950aba13.avi
# ========================================
# Processing: ./dataset/learning/wriggle/2e948f1f-fdb5-427b-b7de-04b261753f72.avi
# ========================================
# Processing: ./dataset/learning/wriggle/8015d995-fd46-44e5-96ff-4b8258beb81e.avi
# ========================================
# Processing: ./dataset/learning/wriggle/5d8af2ea-cd27-4c25-a315-3b1815f0c533.avi
# ========================================
# Processing: ./dataset/learning/wriggle/9832d4e4-6b37-4f49-9f5c-65b05d4bc288.avi
# ========================================
# Processing: ./dataset/learning/wriggle/12d59555-6d45-4138-9352-57fc157d1373.avi
# ========================================
# Processing: ./dataset/learning/wriggle/a6c85e0d-97af-40b4-a930-ebacdb85bce4.avi
# ========================================
# Processing: ./dataset/learning/wriggle/e7defd67-a146-4d62-8c59-55738a9960a2.avi
# ========================================
# Processing: ./dataset/learning/wriggle/09612edb-f80f-4b5d-ba36-20ed16621d1b.avi
# ========================================
# Processing: ./dataset/learning/wriggle/1935653a-179d-405f-a6da-69f7541372d2.avi
# ========================================
# Processing: ./dataset/learning/wriggle/ceb72602-c426-4b51-bf01-907bd4a08516.avi
# ========================================
# Processing: ./dataset/learning/wriggle/36f5713a-29c6-4ed5-b43f-72f1c2184645.avi
# ========================================
# Processing: ./dataset/learning/wriggle/d2198176-ee93-4ad9-b5cc-7805844e866d.avi
# ========================================
# Processing: ./dataset/learning/wriggle/bcea3400-8289-411d-8dbe-8f3903d13854.avi
# ========================================
# Processing: ./dataset/learning/wriggle/f7fe79a4-939d-4164-9703-04440def5e7e.avi
# ========================================
# Processing: ./dataset/learning/wriggle/
avi
# ========================================
# Processing: ./dataset/learning/wriggle/a1c4b665-56d4-4f78-a87c-132eaedc682e.avi
# ========================================
# Processing: ./dataset/learning/wriggle/ff0be725-9097-4dd9-8076-a764d2ebaf5d.avi
# ========================================
# Processing: ./dataset/learning/wriggle/192630d8-94fb-4fc8-96e6-bd62c0aa568a.avi
# ========================================
# Processing: ./dataset/learning/wriggle/cd7a27b0-0cc5-4b93-8fdb-6e623ac59b68.avi
# ========================================
# Processing: ./dataset/learning/wriggle/1f04c03d-92fb-4e53-ae62-175d9785a5f3.avi
# ========================================
# Processing: ./dataset/learning/wriggle/fa3f89b1-6581-467e-88f4-32af119d0722.avi
# ========================================
# Processing: ./dataset/learning/wriggle/83430b56-ea53-4dbd-b43f-50543dd42ca0.avi
# ========================================
# Processing: ./dataset/learning/wriggle/1728b6b5-46cd-446b-8afc-650ddf4f1055.avi
# ========================================
# Processing: ./dataset/learning/wriggle/b7d5bfe3-2871-44ec-bed0-e5d70bb776a9.avi
# ========================================
# Processing: ./dataset/learning/wriggle/adc49484-3bf0-4a40-981f-529d63484304.avi
# ========================================
# Processing: ./dataset/learning/wriggle/5d0bb514-790a-4ede-b3cd-6564cf7895b7.avi
# ========================================
# Processing: ./dataset/learning/wriggle/d4e444e9-6b8a-4399-be39-b74cb09aeead.avi
# ========================================
# Processing: ./dataset/learning/wriggle/3251460e-081f-4c21-bdd5-d61c6bbc2dc8.avi
# ========================================
# Processing: ./dataset/learning/wriggle/8beae52f-8d84-46a0-b46a-af141af89dc2.avi
# ========================================
# Processing: ./dataset/learning/wriggle/8a41a53b-d8c5-48bf-9fc3-f812e1a3f070.avi
# ========================================
# Processing: ./dataset/learning/wriggle/58e3de8a-3046-4d03-970d-defed84c031c.avi
# ========================================
# Processing: ./dataset/learning/wriggle/6b82d10c-9c3c-4b71-9f96-d09c6e49172c.avi
# ========================================
# Processing: ./dataset/learning/wriggle/aa458cb4-ff52-4d51-bee9-34a6ba5ad508.avi
# ========================================
# Processing: ./dataset/learning/wriggle/056e6574-6fc1-4b4e-8963-380e3bdd84a5.avi
# ========================================
# Processing: ./dataset/learning/wriggle/97a3b917-1f74-42a0-bfdc-793fdbfee1d5.avi
# ========================================
# Processing: ./dataset/learning/wriggle/3c26ae9b-8b7a-4888-8147-be55ccb5c748.avi
# ========================================
# Processing: ./dataset/learning/wriggle/69a3d473-26c5-4002-81a1-77a7186af804.avi
# ========================================
# Processing: ./dataset/learning/wriggle/0f7e4439-410b-4402-a429-f25157020d64.avi
# ========================================
# Processing: ./dataset/learning/wriggle/57d4fe35-3821-4ea2-886d-f0e39623ba35.avi
# ========================================
# Processing: ./dataset/learning/wriggle/88039a5e-bbfc-4c09-9dcf-9c7c97b06a5c.avi
# ========================================
# Processing: ./dataset/learning/wriggle/130ec656-4a85-414f-b2e5-ec54a27368d1.avi
# ========================================
# Processing: ./dataset/learning/wriggle/7b5841cb-621c-49af-897f-352abc5e42c9.avi
# ========================================
# Processing: ./dataset/learning/wriggle/cf5e5c88-fbb8-48d4-a60e-d199ab065cf3.avi
# ========================================
# Processing: ./dataset/learning/wriggle/c1b26463-77dd-490e-add5-f1a61f61db54.avi
# ========================================
# Processing: ./dataset/learning/wriggle/441239c7-0ca3-4cf0-baf2-1d07ef05bc60.avi
# ========================================
# Processing: ./dataset/learning/wriggle/5d5787c3-b64c-46ac-ad74-aeac18be3dff.avi
# ========================================
# Processing: ./dataset/learning/wriggle/fa7c4993-2e55-4986-a258-98c44372276a.avi
# ========================================
# Processing: ./dataset/learning/wriggle
.avi
# ========================================
# Processing: ./dataset/learning/wriggle/b6a91c98-368d-4a43-b642-6b9cdf66d50c.avi
# ========================================
# Processing: ./dataset/learning/wriggle/0d27c5e8-d910-4465-a77c-2f91f91158ef.avi
# ========================================
# Processing: ./dataset/learning/wriggle/512a8fe7-90ad-4844-922e-67e83bdff3d8.avi
# ========================================
# Processing: ./dataset/learning/wriggle/ba0ae525-292d-4a2a-bfe8-f5f51aea2a0b.avi
# ========================================
# Processing: ./dataset/learning/wriggle/cd4179a6-80f3-4b6b-9081-6cc3ed646535.avi
# ========================================
# Processing: ./dataset/learning/wriggle/3eb3d508-cfd3-4d18-90b7-a52524ce9386.avi
# ========================================
# Processing: ./dataset/learning/wriggle/665d36fa-1786-442d-90e2-f440d22344c2.avi
# ========================================
# Processing: ./dataset/learning/wriggle/906b2f7c-c80d-45f6-a3f9-b99e249d9ce7.avi
# ========================================
# Processing: ./dataset/learning/wriggle/e3fbb56f-ebad-43c1-ae45-8a36c3a894cc.avi
# ========================================
# Processing: ./dataset/learning/wriggle/750bb4cd-44d1-4e03-b9f2-e346f41ff396.avi
# ========================================
# Processing: ./dataset/learning/wriggle/6cbc975c-d6ef-4d3f-923f-d297903d9742.avi
# ========================================
# Processing: ./dataset/learning/wriggle/56e4bf28-c082-47a3-a5eb-aae439592422.avi
# ========================================
# Processing: ./dataset/learning/wriggle/11291a31-f1d2-4fe3-ae72-595fec97092e.avi
# ========================================
# Processing: ./dataset/learning/wriggle/9edf7834-bd65-4ec8-8f22-9e63a9e49aa5.avi
# ========================================
# Processing: ./dataset/learning/wriggle/4dee2d5d-0177-4633-bdff-b9559989010e.avi
# ========================================
# Processing: ./dataset/learning/wriggle/b6016397-e592-40bc-9fee-165103fb2983.avi
# ========================================
# Processing: ./dataset/learning/wriggle/c30e2a78-5c0d-4e90-88df-cd0e727addba.avi
# ========================================
# Processing: ./dataset/learning/wriggle/8b60f8ab-9a6f-47a2-ab96-706ce7aa0385.avi
# ========================================
# Processing: ./dataset/learning/wriggle/b4cdc112-4237-4b5d-ac81-5928154d89f5.avi
# ========================================
# Processing: ./dataset/learning/wriggle/46b44d92-2289-439b-8727-67edd6d57ca0.avi
# ========================================
# Processing: ./dataset/learning/wriggle/4f49f634-7356-4bec-9a16-fe3bd5d0b89a.avi
# ========================================
# Processing: ./dataset/learning/wriggle/a993a6b4-c46b-41fd-a8ac-b120d1ec7aad.avi
# ========================================
# Processing: ./dataset/learning/wriggle/7d10e712-be05-4fc4-a530-86ee0509386e.avi
# ========================================
# Processing: ./dataset/learning/wriggle/156463c5-0b9c-44a1-a98d-027ae187027a.avi
# ========================================
# Processing: ./dataset/learning/wriggle/20f38acf-943b-4141-ad60-0aa5bcc9f5ca.avi
# ========================================
# Processing: ./dataset/learning/wriggle/39ee1820-8fad-46e7-89a7-6e85c20f2260.avi
# ========================================
# Processing: ./dataset/learning/wriggle/9e74c4a6-803f-4788-b632-0927e5874dc2.avi
# ========================================
# Processing: ./dataset/learning/wriggle/174ef038-a9f8-4284-81fd-4a23a1b94f4b.avi
# ========================================
# Processing: ./dataset/learning/wriggle/aff24b18-4f07-410b-b270-a7a4ffbe0d37.avi
# ========================================
# Processing: ./dataset/learning/wriggle/f3e4a368-abcd-4b22-931e-f029f17940d4.avi
# ========================================
# Processing: ./dataset/learning/wriggle/0dcecc6c-8966-41e8-90a9-bc373b74e668.avi
# ========================================
# Complete
