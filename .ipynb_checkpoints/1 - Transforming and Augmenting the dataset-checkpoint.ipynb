# %%
# https://imgaug.readthedocs.io/en/latest/index.html

import cv2
import os
from pathlib import Path
import imgaug as ia
import imageio
from imgaug import augmenters as iaa
import shutil
import argparse
import random

# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.20.0'

# %%
sometimes = lambda aug: iaa.Sometimes(0.5, aug)


def apply_transformations(video_reader,fps,w,h,output_path):
    """
        Fetch each frame of video and augment and save as picture in a temporary folder
        Args:
            video_reader: Video reader object
            rotation_angle: int (Angle of rotation of image)
            noise_value: int (noise value between 0 to 100)
            temp_folder_path: string (temporary path to store video frames)
            output_folder_path: string (output folder path)
            video_clip_name: string (video name)
            i: no of clip augmented
    """
    


    
    #print(editted_name, rotation_angle, "degrees")
    seq = iaa.Sequential([
        #iaa.Fliplr(0.5), # horizontal flips
        #iaa.Crop(percent=(0, 0.1)), # random crops
        # Small gaussian blur with random sigma between 0 and 0.5.
        # But we only blur about 50% of all images.
        iaa.OneOf([
            iaa.GaussianBlur((0, 3.0)),
            iaa.AverageBlur(k=(2, 7)),
            iaa.MedianBlur(k=(3, 11)),
        ]),
        # Strengthen or weaken the contrast in each image.
        sometimes(
            iaa.LinearContrast((0.75, 1.5))
        ),
        sometimes(
            iaa.ElasticTransformation(alpha=(0.5, 3.5), sigma=0.25)
        ),

        # In some images distort local areas with varying strength.
        #sometimes(iaa.PiecewiseAffine(scale=(0.01, 0.05)))
        #)
    ], random_order=True) 

  

    #fourcc = '.avi'  # output video codec
    video_writer = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'XVID'),fps,(w,h))

    try:
        while video_reader.isOpened():
            ret, frame = video_reader.read()
            if not ret:
                break
            image_aug = seq(image=frame)
            video_writer.write(image_aug)
    except Exception as e:
        print(e)

    cv2.destroyAllWindows()
    video_reader.release()
    video_writer.release()

# %%
def get_videos_info(directory, extensions):
    videos_info = []

    for root, dirs, files in os.walk(directory):
        for file in files:
            if any(file.lower().endswith(ext) for ext in extensions):
                videos_info.append({
                    'name': file,
                    'path': os.path.join(root, file),
                    'directory': root
                })

    return videos_info

# %%
def transform_videos(videos_info):
    
    
    for video in videos_info:

        name = video['name']
        path = video['path']
        dir  = video['directory']
        
        print("Processing:", path)
        video_reader = cv2.VideoCapture(path)
        fps = int(video_reader.get(cv2.CAP_PROP_FPS))
        w = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))
        h = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))
                
        transformed_video_path = dir + f'/aug_{name}'
                
        apply_transformations(video_reader,fps,w,h,transformed_video_path)
        print("=" * 40)
    

    print("Complete")

# %%
videos_info = get_videos_info('./dataset', 'avi')

transform_videos(videos_info)
# Out:
# Processing: ./dataset/slip/right_27464d58.avi
# ========================================
# Processing: ./dataset/slip/left_7d512662.avi
# ========================================
# Processing: ./dataset/slip/left_3291fd19.avi
# ========================================
# Processing: ./dataset/slip/left_150453ca.avi
# ========================================
# Processing: ./dataset/slip/right_1213f9e9.avi
# ========================================
# Processing: ./dataset/slip/right_437b403e.avi
# ========================================
# Processing: ./dataset/slip/left_e72b9074.avi
# ========================================
# Processing: ./dataset/slip/right_1604f737.avi
# ========================================
# Processing: ./dataset/slip/left_cea7f60f.avi
# ========================================
# Processing: ./dataset/slip/right_935ead60.avi
# ========================================
# Processing: ./dataset/slip/left_0329a84b.avi
# ========================================
# Processing: ./dataset/slip/right_9981bc21.avi
# ========================================
# Processing: ./dataset/slip/right_5084f21a.avi
# ========================================
# Processing: ./dataset/slip/right_ac44e8c9.avi
# ========================================
# Processing: ./dataset/slip/left_6e9b8819.avi
# ========================================
# Processing: ./dataset/slip/left_ced35442.avi
# ========================================
# Processing: ./dataset/slip/left_c8f0c197.avi
# ========================================
# Processing: ./dataset/slip/right_a3b96a10.avi
# ========================================
# Processing: ./dataset/slip/right_6a3e77e9.avi
# ========================================
# Processing: ./dataset/slip/left_bf43e0c8.avi
# ========================================
# Processing: ./dataset/slip/left_31c2b350.avi
# ========================================
# Processing: ./dataset/slip/right_6c6f54e7.avi
# ========================================
# Processing: ./dataset/slip/right_ef10adda.avi
# ========================================
# Processing: ./dataset/slip/right_da4391c2.avi
# ========================================
# Processing: ./dataset/slip/left_60f79769.avi
# ========================================
# Processing: ./dataset/slip/left_367f723f.avi
# ========================================
# Processing: ./dataset/slip/right_66ba77e6.avi
# ========================================
# Processing: ./dataset/slip/left_df912b1f.avi
# ========================================
# Processing: ./dataset/slip/right_9c5b99b7.avi
# ========================================
# Processing: ./dataset/slip/right_024b99ad.avi
# ========================================
# Processing: ./dataset/slip/left_9f13e9a5.avi
# ========================================
# Processing: ./dataset/slip/right_eb168057.avi
# ========================================
# Processing: ./dataset/slip/aug_right_27464d58.avi
# ========================================
# Processing: ./dataset/slip/right_c1eefc69.avi
# ========================================
# Processing: ./dataset/slip/left_84bfe7e3.avi
# ========================================
# Processing: ./dataset/slip/right_f3e18bd4.avi
# ========================================
# Processing: ./dataset/slip/left_9c20930c.avi
# ========================================
# Processing: ./dataset/slip/right_c7e4ea17.avi
# ========================================
# Processing: ./dataset/slip/left_f78a6a5d.avi
# ========================================
# Processing: ./dataset/slip/right_a5f2ce03.avi
# ========================================
# Processing: ./dataset/slip/left_9fe3dc07.avi
# ========================================
# Processing: ./dataset/slip/right_b8a4fa66.avi
# ========================================
# Processing: ./dataset/slip/right_631201f7.avi
# ========================================
# Processing: ./dataset/slip/left_91fb2250.avi
# ========================================
# Processing: ./dataset/slip/right_c25e51e3.avi
# ========================================
# Processing: ./dataset/slip/right_a45e751e.avi
# ========================================
# Processing: ./dataset/slip/right_7e8a16a0.avi
# ========================================
# Processing: ./dataset/slip/right_d64dcaa4.avi
# ========================================
# Processing: ./dataset/slip/left_493a2407.avi
# ========================================
# Processing: ./dataset/slip/left_2ac33364.avi
# ========================================
# Processing: ./dataset/slip/left_52346115.avi
# ========================================
# Processing: ./dataset/slip/right_87df5bac.avi
# ========================================
# Processing: ./dataset/slip/left_2b9879de.avi
# ========================================
# Processing: ./dataset/slip/left_7f1d64e7.avi
# ========================================
# Processing: ./dataset/slip/left_2525b474.avi
# ========================================
# Processing: ./dataset/slip/right_4acf4aad.avi
# ========================================
# Processing: ./dataset/slip/left_da7645ea.avi
# ========================================
# Processing: ./dataset/slip/left_47337763.avi
# ========================================
# Processing: ./dataset/slip/left_04a80413.avi
# ========================================
# Processing: ./dataset/slip/left_778a17c5.avi
# ========================================
# Processing: ./dataset/slip/left_980e3468.avi
# ========================================
# Processing: ./dataset/slip/right_71ab2002.avi
# ========================================
# Processing: ./dataset/slip/left_fd3defec.avi
# ========================================
# Processing: ./dataset/slip/right_95fcee38.avi
# ========================================
# Processing: ./dataset/slip/right_587cec2f.avi
# ========================================
# Processing: ./dataset/slip/right_86f5ec04.avi
# ========================================
# Processing: ./dataset/slip/right_6fb6ec8c.avi
# ========================================
# Processing: ./dataset/slip/right_f7ff9076.avi
# ========================================
# Processing: ./dataset/slip/right_c759ae3e.avi
# ========================================
# Processing: ./dataset/slip/left_3ff70dd8.avi
# ========================================
# Processing: ./dataset/slip/left_d4dff7ef.avi
# ========================================
# Processing: ./dataset/slip/left_b0630ee1.avi
# ========================================
# Processing: ./dataset/slip/left_64ce8d16.avi
# ========================================
# Processing: ./dataset/slip/right_399f6ade.avi
# ========================================
# Processing: ./dataset/slip/right_aba37389.avi
# ========================================
# Processing: ./dataset/slip/left_162b4a40.avi
# ========================================
# Processing: ./dataset/slip/left_9c856d69.avi
# ========================================
# Processing: ./dataset/slip/left_fa47b02b.avi
# ========================================
# Processing: ./dataset/slip/right_f9361019.avi
# ========================================
# Processing: ./dataset/slip/right_a49d1d0c.avi
# ========================================
# Processing: ./dataset/slip/left_a1f8b310.avi
# ========================================
# Processing: ./dataset/slip/left_fa44bf60.avi
# ========================================
# Processing: ./dataset/slip/right_01cf33e9.avi
# ========================================
# Processing: ./dataset/slip/right_51d4597a.avi
# ========================================
# Processing: ./dataset/slip/right_a35e3220.avi
# ========================================
# Processing: ./dataset/slip/left_7d6fea4c.avi
# ========================================
# Processing: ./dataset/slip/left_85a05582.avi
# ========================================
# Processing: ./dataset/slip/right_887bd5b1.avi
# ========================================
# Processing: ./dataset/slip/left_dce7bdd6.avi
# ========================================
# Processing: ./dataset/slip/left_7d9c8897.avi
# ========================================
# Processing: ./dataset/slip/right_adc5aaba.avi
# ========================================
# Processing: ./dataset/wriggle/right_289df642.avi
# ========================================
# Processing: ./dataset/wriggle/right_711fd89f.avi
# ========================================
# Processing: ./dataset/wriggle/left_cd754746.avi
# ========================================
# Processing: ./dataset/wriggle/right_b397dced.avi
# ========================================
# Processing: ./dataset/wriggle/left_a2a80ecf.avi
# ========================================
# Processing: ./dataset/wriggle/left_b9a630be.avi
# ========================================
# Processing: ./dataset/wriggle/right_c87c37ac.avi
# ========================================
# Processing: ./dataset/wriggle/left_f854e6d2.avi
# ========================================
# Processing: ./dataset/wriggle/left_fd18c1d9.avi
# ========================================
# Processing: ./dataset/wriggle/left_d915147e.avi
# ========================================
# Processing: ./dataset/wriggle/left_3a350358.avi
# ========================================
# Processing: ./dataset/wriggle/left_7d2336bd.avi
# ========================================
# Processing: ./dataset/wriggle/left_a5323d1b.avi
# ========================================
# Processing: ./dataset/wriggle/left_de71d870.avi
# ========================================
# Processing: ./dataset/wriggle/right_54499caf.avi
# ========================================
# Processing: ./dataset/wriggle/left_86e2d4c9.avi
# ========================================
# Processing: ./dataset/wriggle/right_7e291fda.avi
# ========================================
# Processing: ./dataset/wriggle/right_58ea4951.avi
# ========================================
# Processing: ./dataset/wriggle/right_e5824d05.avi
# ========================================
# Processing: ./dataset/wriggle/left_672ea0fc.avi
# ========================================
# Processing: ./dataset/wriggle/left_28ae03dd.avi
# ========================================
# Processing: ./dataset/wriggle/left_80e7c2ca.avi
# ========================================
# Processing: ./dataset/wriggle/left_567aff86.avi
# ========================================
# Processing: ./dataset/wriggle/left_a39dd50e.avi
# ========================================
# Processing: ./dataset/wriggle/left_73350ca6.avi
# ========================================
# Processing: ./dataset/wriggle/left_050d8199.avi
# ========================================
# Processing: ./dataset/wriggle/left_8c6b21cd.avi
# ========================================
# Processing: ./dataset/wriggle/left_c15e42c8.avi
# ========================================
# Processing: ./dataset/wriggle/left_f7e09c13.avi
# ========================================
# Processing: ./dataset/wriggle/right_b07c9602.avi
# ========================================
# Processing: ./dataset/wriggle/left_5398f607.avi
# ========================================
# Processing: ./dataset/wriggle/right_220d76df.avi
# ========================================
# Processing: ./dataset/wriggle/right_93eeb76a.avi
# ========================================
# Processing: ./dataset/wriggle/right_15b188db.avi
# ========================================
# Processing: ./dataset/wriggle/left_08fcfa6f.avi
# ========================================
# Processing: ./dataset/wriggle/left_656b639c.avi
# ========================================
# Processing: ./dataset/wriggle/left_38c7e0d3.avi
# ========================================
# Processing: ./dataset/wriggle/left_314167ed.avi
# ========================================
# Processing: ./dataset/wriggle/right_cf82ddb4.avi
# ========================================
# Processing: ./dataset/wriggle/right_97ee8c53.avi
# ========================================
# Processing: ./dataset/wriggle/right_30e7cd82.avi
# ========================================
# Processing: ./dataset/wriggle/right_cca98fd8.avi
# ========================================
# Processing: ./dataset/wriggle/left_f66999b9.avi
# ========================================
# Processing: ./dataset/wriggle/left_b556ad89.avi
# ========================================
# Processing: ./dataset/wriggle/right_cc4023bc.avi
# ========================================
# Processing: ./dataset/wriggle/left_3995ae61.avi
# ========================================
# Processing: ./dataset/wriggle/left_e8df719c.avi
# ========================================
# Processing: ./dataset/wriggle/left_d7f4827e.avi
# ========================================
# Processing: ./dataset/wriggle/left_521bc2e0.avi
# ========================================
# Processing: ./dataset/wriggle/right_e1daa34b.avi
# ========================================
# Processing: ./dataset/wriggle/left_8c0ee3fc.avi
# ========================================
# Processing: ./dataset/wriggle/left_974ecf35.avi
# ========================================
# Processing: ./dataset/wriggle/left_1f7ac79a.avi
# ========================================
# Processing: ./dataset/wriggle/right_fd4fbe5a.avi
# ========================================
# Processing: ./dataset/wriggle/left_8da63504.avi
# ========================================
# Processing: ./dataset/wriggle/right_9e915d6f.avi
# ========================================
# Processing: ./dataset/wriggle/right_5adc11fd.avi
# ========================================
# Processing: ./dataset/wriggle/right_eb07315c.avi
# ========================================
# Processing: ./dataset/wriggle/right_5814123e.avi
# ========================================
# Processing: ./dataset/wriggle/right_34535321.avi
# ========================================
# Processing: ./dataset/wriggle/right_b7cf9da4.avi
# ========================================
# Processing: ./dataset/wriggle/right_cbd558ed.avi
# ========================================
# Processing: ./dataset/wriggle/right_db633b28.avi
# ========================================
# Processing: ./dataset/wriggle/left_da589114.avi
# ========================================
# Processing: ./dataset/wriggle/left_dcac0c73.avi
# ========================================
# Processing: ./dataset/wriggle/left_8538f599.avi
# ========================================
# Processing: ./dataset/wriggle/right_95b7b8b5.avi
# ========================================
# Processing: ./dataset/wriggle/right_1c40d160.avi
# ========================================
# Processing: ./dataset/wriggle/left_128f3ec9.avi
# ========================================
# Processing: ./dataset/wriggle/left_894f48fd.avi
# ========================================
# Processing: ./dataset/wriggle/right_9a959abf.avi
# ========================================
# Processing: ./dataset/wriggle/right_db7c436b.avi
# ========================================
# Processing: ./dataset/wriggle/left_c339f4de.avi
# ========================================
# Processing: ./dataset/wriggle/left_7c294ac5.avi
# ========================================
# Processing: ./dataset/wriggle/left_ca4ca0cc.avi
# ========================================
# Processing: ./dataset/wriggle/left_ed5dff56.avi
# ========================================
# Processing: ./dataset/wriggle/right_1dd4b187.avi
# ========================================
# Processing: ./dataset/wriggle/left_bb5c4306.avi
# ========================================
# Processing: ./dataset/wriggle/right_5c2cd636.avi
# ========================================
# Processing: ./dataset/wriggle/left_a49f114a.avi
# ========================================
# Processing: ./dataset/wriggle/left_58da88bc.avi
# ========================================
# Processing: ./dataset/wriggle/left_493c7dbb.avi
# ========================================
# Processing: ./dataset/wriggle/left_6819810f.avi
# ========================================
# Processing: ./dataset/wriggle/left_a430fa19.avi
# ========================================
# Processing: ./dataset/wriggle/right_87298896.avi
# ========================================
# Processing: ./dataset/wriggle/right_537c1bd8.avi
# ========================================
# Processing: ./dataset/wriggle/right_897571f3.avi
# ========================================
# Processing: ./dataset/wriggle/right_d050b7fb.avi
# ========================================
# Processing: ./dataset/wriggle/left_aab2cdb0.avi
# ========================================
# Processing: ./dataset/wriggle/right_9da7a96f.avi
# ========================================
# Processing: ./dataset/wriggle/left_477bea79.avi
# ========================================
# Processing: ./dataset/wriggle/right_96a9e418.avi
# ========================================
# Processing: ./dataset/wriggle/left_2347b8d9.avi
# ========================================
# Processing: ./dataset/wriggle/right_17da3db2.avi
# ========================================
# Processing: ./dataset/wriggle/left_0bc27052.avi
# ========================================
# Processing: ./dataset/wriggle/left_af68857f.avi
# ========================================
# Processing: ./dataset/wriggle/right_af45112e.avi
# ========================================
# Processing: ./dataset/wriggle/right_a4190b66.avi
# ========================================
# Processing: ./dataset/wriggle/right_d04ddefa.avi
# ========================================
# Processing: ./dataset/wriggle/right_05a7b7a2.avi
# ========================================
# Processing: ./dataset/wriggle/right_f5ef1a75.avi
# ========================================
# Processing: ./dataset/wriggle/left_40b8cbea.avi
# ========================================
# Processing: ./dataset/wriggle/left_d37b856e.avi
# ========================================
# Processing: ./dataset/wriggle/left_b61b1886.avi
# ========================================
# Processing: ./dataset/wriggle/right_d03c9db7.avi
# ========================================
# Processing: ./dataset/wriggle/right_d0d93e1d.avi
# ========================================
# Processing: ./dataset/wriggle/right_2d8ffb1b.avi
# ========================================
# Processing: ./dataset/wriggle/right_713ed9ee.avi
# ========================================
# Processing: ./dataset/wriggle/left_c0befebc.avi
# ========================================
# Processing: ./dataset/wriggle/right_33adb381.avi
# ========================================
# Processing: ./dataset/wriggle/right_ded17657.avi
# ========================================
# Processing: ./dataset/wriggle/left_fc85ad52.avi
# ========================================
# Processing: ./dataset/wriggle/right_0794a54e.avi
# ========================================
# Processing: ./dataset/wriggle/right_3d7e5771.avi
# ========================================
# Processing: ./dataset/wriggle/right_4c17ec5d.avi
# ========================================
# Processing: ./dataset/wriggle/right_a3887ddb.avi
# ========================================
# Processing: ./dataset/wriggle/left_c1370073.avi
# ========================================
# Processing: ./dataset/wriggle/left_bea62f6e.avi
# ========================================
# Processing: ./dataset/wriggle/left_08a67949.avi
# ========================================
# Processing: ./dataset/wriggle/right_ae5b8d6b.avi
# ========================================
# Processing: ./dataset/wriggle/right_6d548880.avi
# ========================================
# Processing: ./dataset/wriggle/left_6ba3e70c.avi
# ========================================
# Processing: ./dataset/wriggle/left_85cfee86.avi
# ========================================
# Processing: ./dataset/wriggle/left_f9f2e081.avi
# ========================================
# Processing: ./dataset/wriggle/right_425e400e.avi
# ========================================
# Processing: ./dataset/wriggle/right_049b62a1.avi
# ========================================
# Processing: ./dataset/wriggle/right_0f6bcffb.avi
# ========================================
# Processing: ./dataset/wriggle/left_23d355c2.avi
# ========================================
# Processing: ./dataset/wriggle/right_3ae58fd6.avi
# ========================================
# Processing: ./dataset/wriggle/left_46c712fc.avi
# ========================================
# Processing: ./dataset/wriggle/left_c91acd30.avi
# ========================================
# Processing: ./dataset/wriggle/right_9c583544.avi
# ========================================
# Processing: ./dataset/wriggle/left_e20e7f83.avi
# ========================================
# Processing: ./dataset/wriggle/right_67f6e0b9.avi
# ========================================
# Processing: ./dataset/wriggle/right_1f0ecd9f.avi
# ========================================
# Processing: ./dataset/wriggle/left_177660d2.avi
# ========================================
# Processing: ./dataset/wriggle/left_620a417a.avi
# ========================================
# Processing: ./dataset/wriggle/right_dc8e9bb5.avi
# ========================================
# Processing: ./dataset/wriggle/left_239b7e3e.avi
# ========================================
# Processing: ./dataset/wriggle/left_5192017b.avi
# ========================================
# Processing: ./dataset/wriggle/right_42631feb.avi
# ========================================
# Processing: ./dataset/wriggle/right_5023c4ee.avi
# ========================================
# Processing: ./dataset/wriggle/right_64340c6b.avi
# ========================================
# Processing: ./dataset/wriggle/left_84eb5eb8.avi
# ========================================
# Processing: ./dataset/wriggle/right_6e52c94a.avi
# ========================================
# Processing: ./dataset/wriggle/right_825f416e.avi
# ========================================
# Processing: ./dataset/wriggle/right_53940700.avi
# ========================================
# Processing: ./dataset/wriggle/right_a84a52be.avi
# ========================================
# Processing: ./dataset/wriggle/right_b0e96c7b.avi
# ========================================
# Processing: ./dataset/wriggle/right_0490db46.avi
# ========================================
# Processing: ./dataset/wriggle/right_ab3a597e.avi
# ========================================
# Processing: ./dataset/wriggle/right_ee4b0fcb.avi
# ========================================
# Processing: ./dataset/wriggle/left_c3b0cf7a.avi
# ========================================
# Processing: ./dataset/wriggle/left_bcab04f8.avi
# ========================================
# Processing: ./dataset/wriggle/left_f0a4882d.avi
# ========================================
# Processing: ./dataset/wriggle/left_3b7a213e.avi
# ========================================
# Processing: ./dataset/wriggle/right_c97964fe.avi
# ========================================
# Processing: ./dataset/wriggle/right_b5494ae7.avi
# ========================================
# Processing: ./dataset/wriggle/right_fa5e25e1.avi
# ========================================
# Processing: ./dataset/wriggle/left_b10ab158.avi
# ========================================
# Processing: ./dataset/wriggle/left_e6845e27.avi
# ========================================
# Processing: ./dataset/wriggle/left_d09d0e9e.avi
# ========================================
# Processing: ./dataset/wriggle/right_f1f44b20.avi
# ========================================
# Processing: ./dataset/wriggle/left_16cc8d78.avi
# ========================================
# Processing: ./dataset/wriggle/left_a4f6a3c7.avi
# ========================================
# Processing: ./dataset/wriggle/right_ed8b73bf.avi
# ========================================
# Processing: ./dataset/wriggle/right_98e1263f.avi
# ========================================
# Processing: ./dataset/wriggle/right_4ea0b403.avi
# ========================================
# Processing: ./dataset/wriggle/right_e49df3fb.avi
# ========================================
# Processing: ./dataset/wriggle/left_b77d90b3.avi
# ========================================
# Processing: ./dataset/wriggle/right_1cca2f2a.avi
# ========================================
# Processing: ./dataset/wriggle/right_ab93d234.avi
# ========================================
# Processing: ./dataset/wriggle/left_9ff5c4f1.avi
# ========================================
# Processing: ./dataset/wriggle/left_d8e72958.avi
# ========================================
# Processing: ./dataset/wriggle/right_915db882.avi
# ========================================
# Processing: ./dataset/wriggle/left_0429b6fe.avi
# ========================================
# Processing: ./dataset/wriggle/left_2a9a511a.avi
# ========================================
# Processing: ./dataset/wriggle/left_13cc7360.avi
# ========================================
# Processing: ./dataset/wriggle/left_72063dbe.avi
# ========================================
# Processing: ./dataset/wriggle/left_43467bdc.avi
# ========================================
# Processing: ./dataset/wriggle/left_06c5e9f5.avi
# ========================================
# Processing: ./dataset/wriggle/right_c7de2a18.avi
# ========================================
# Processing: ./dataset/wriggle/right_a8ca1c4b.avi
# ========================================
# Processing: ./dataset/wriggle/right_f530390f.avi
# ========================================
# Processing: ./dataset/wriggle/left_293dd05a.avi
# ========================================
# Processing: ./dataset/wriggle/left_29b5dee4.avi
# ========================================
# Processing: ./dataset/wriggle/right_2800fbfe.avi
# ========================================
# Processing: ./dataset/wriggle/right_a5424a67.avi
# ========================================
# Processing: ./dataset/wriggle/left_7d98bd39.avi
# ========================================
# Processing: ./dataset/wriggle/right_70029550.avi
# ========================================
# Processing: ./dataset/wriggle/right_91535a02.avi
# ========================================
# Processing: ./dataset/wriggle/left_48e71efa.avi
# ========================================
# Processing: ./dataset/wriggle/left_f50b3aaa.avi
# ========================================
# Processing: ./dataset/wriggle/right_8d816987.avi
# ========================================
# Processing: ./dataset/wriggle/left_ab46a929.avi
# ========================================
# Processing: ./dataset/wriggle/right_59207281.avi
# ========================================
# Processing: ./dataset/wriggle/right_991d3b2f.avi
# ========================================
# Processing: ./dataset/wriggle/right_d1d70822.avi
# ========================================
# Processing: ./dataset/wriggle/right_4c236507.avi
# ========================================
# Processing: ./dataset/wriggle/right_c58044f0.avi
# ========================================
# Processing: ./dataset/wriggle/left_773709ab.avi
# ========================================
# Processing: ./dataset/wriggle/left_59901327.avi
# ========================================
# Processing: ./dataset/wriggle/right_1cbdab93.avi
# ========================================
# Processing: ./dataset/wriggle/left_5151c66a.avi
# ========================================
# Processing: ./dataset/wriggle/left_40b5ef57.avi
# ========================================
# Processing: ./dataset/wriggle/right_dd147d24.avi
# ========================================
# Processing: ./dataset/wriggle/left_005d3910.avi
# ========================================
# Processing: ./dataset/wriggle/right_fe781863.avi
# ========================================
# Processing: ./dataset/wriggle/right_f9ca94c3.avi
# ========================================
# Processing: ./dataset/wriggle/right_cd085774.avi
# ========================================
# Processing: ./dataset/wriggle/right_a456aefd.avi
# ========================================
# Processing: ./dataset/wriggle/left_2f6bf064.avi
# ========================================
# Processing: ./dataset/wriggle/left_31d03bff.avi
# ========================================
# Processing: ./dataset/wriggle/right_2b102a66.avi
# ========================================
# Processing: ./dataset/wriggle/right_3c2027fa.avi
# ========================================
# Processing: ./dataset/wriggle/left_7631fdbd.avi
# ========================================
# Processing: ./dataset/wriggle/right_3cbbb6d0.avi
# ========================================
# Processing: ./dataset/wriggle/right_7a97d828.avi
# ========================================
# Processing: ./dataset/wriggle/left_ff84429d.avi
# ========================================
# Processing: ./dataset/wriggle/right_b288ea64.avi
# ========================================
# Processing: ./dataset/wriggle/left_0c99e659.avi
# ========================================
# Processing: ./dataset/wriggle/left_c890ba27.avi
# ========================================
# Processing: ./dataset/wriggle/left_53191c56.avi
# ========================================
# Processing: ./dataset/wriggle/right_078d3364.avi
# ========================================
# Processing: ./dataset/wriggle/left_09d36b2f.avi
# ========================================
# Processing: ./dataset/wriggle/right_690391e0.avi
# ========================================
# Processing: ./dataset/wriggle/right_77a155b6.avi
# ========================================
# Processing: ./dataset/wriggle/left_85b65b0c.avi
# ========================================
# Processing: ./dataset/wriggle/right_9047792b.avi
# ========================================
# Processing: ./dataset/wriggle/left_0369a3b8.avi
# ========================================
# Processing: ./dataset/wriggle/left_f369664e.avi
# ========================================
# Processing: ./dataset/wriggle/left_e888b003.avi
# ========================================
# Processing: ./dataset/wriggle/right_39300ee5.avi
# ========================================
# Processing: ./dataset/wriggle/right_ae66f8c5.avi
# ========================================
# Processing: ./dataset/wriggle/right_80b7e72c.avi
# ========================================
# Processing: ./dataset/wriggle/right_0790dd96.avi
# ========================================
# Processing: ./dataset/wriggle/right_5a4b3762.avi
# ========================================
# Processing: ./dataset/wriggle/right_eb9259a9.avi
# ========================================
# Processing: ./dataset/wriggle/right_f021d2f1.avi
# ========================================
# Processing: ./dataset/wriggle/left_e737b7d4.avi
# ========================================
# Processing: ./dataset/wriggle/right_f3778362.avi
# ========================================
# Processing: ./dataset/wriggle/left_455dade8.avi
# ========================================
# Processing: ./dataset/wriggle/left_426308d1.avi
# ========================================
# Processing: ./dataset/wriggle/left_62cb7340.avi
# ========================================
# Processing: ./dataset/wriggle/left_733b660b.avi
# ========================================
# Processing: ./dataset/wriggle/right_a1c9b25d.avi
# ========================================
# Processing: ./dataset/wriggle/left_e68ca1aa.avi
# ========================================
# Processing: ./dataset/wriggle/left_fa05204f.avi
# ========================================
# Complete
