# %%
from __future__ import print_function


import os

import matplotlib.pyplot as plt
import numpy as np
import torch
import seaborn as sns
from matplotlib import cm
from matplotlib.colors import Normalize
from matplotlib.collections import LineCollection


torch.device('cpu')
# Out:
# device(type='cpu')

# %%
checkpoint_folder = './checkpoints'

# %%
# Initialize lists to store loss values and epochs
losses = []
epochs = []

# Iterate over all .pt files in the checkpoint folder
for filename in os.listdir(checkpoint_folder):
    if filename.endswith('.pt'):
        checkpoint_path = os.path.join(checkpoint_folder, filename)
        
        # Load the checkpoint
        checkpoint = torch.load(checkpoint_path)
        
        # Extract the loss values and epoch from the checkpoint
        checkpoint_losses = checkpoint['loss']
        checkpoint_epochs = checkpoint['epoch']
        
        # Append the loss values and epochs to the respective lists
        losses.append(checkpoint_losses)
        epochs.append(checkpoint_epochs)

# %%
# Combine losses and epochs and sort by epoch values
loss_epoch_pairs = list(zip(losses, epochs))
loss_epoch_pairs.sort(key=lambda x: x[1])
losses, epochs = zip(*loss_epoch_pairs)

# %%
# Plot the loss curve
plt.rcParams["font.family"] = "Times New Roman"

sns.set_theme(style='whitegrid', palette='deep', font_scale=1, color_codes=True, rc=None)

# %%
# Normalize the losses for colormap
norm = Normalize(vmin=min(losses), vmax=max(losses))

# Define a custom colormap (you can choose any colormap you like)
custom_cmap = cm.get_cmap('winter')  # 'viridis' is an example colormap

# Create a LineCollection for the loss curve with color mapping
points = np.column_stack((epochs, losses))
segments = np.stack((points[:-1], points[1:]), axis=1)
lc = LineCollection(segments, cmap=custom_cmap, norm=norm)
lc.set_array(losses)

# Plot the loss curve with color mapping as a line plot
plt.figure(figsize=(10, 6))
plt.gca().add_collection(lc)
plt.colorbar(lc, label='Loss Value', format='%.2f', pad=0.1)  # Add a colorbar with padding

# Plot the loss curve as a scatter plot with decreased marker size
plt.scatter(epochs, losses, c=losses, cmap=custom_cmap, marker='o', s=10, zorder=10)

plt.xlabel('Epochs', labelpad=10)  # Add padding to the x-axis label
plt.ylabel('Losses', labelpad=10)  # Add padding to the y-axis label
plt.title(' Training Loss Curve', pad=10)  # Add padding to the title
plt.grid(True)

plt.show()
# Out:
# /tmp/ipykernel_1675471/2236248896.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   custom_cmap = cm.get_cmap('winter')  # 'viridis' is an example colormap
